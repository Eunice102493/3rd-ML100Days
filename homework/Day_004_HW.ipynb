# %%
import pandas as pd
from google.colab import files
files.upload()
home_de=pd.read_excel('HomeCredit_columns_description1.xlsx')
# Out:
#      <input type="file" id="files-3abc0395-e029-4389-8e09-c2853d01e98f" name="files[]" multiple disabled />
#      <output id="result-3abc0395-e029-4389-8e09-c2853d01e98f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HomeCredit_columns_description1.xlsx to HomeCredit_columns_description1 (1).xlsx

# %%
 print('columns數 %s' %len(home_de.columns))
print('row數 %s' %len(home_de.index))
# Out:
# columns數 7
# row數 205

# %%
home_de.columns
# Out:
# Index(['Unnamed: 0', 'Table', 'Row', 'Description', 'Special', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
home_de.iloc[:,0:5]
# Out:
#      Unnamed: 0  ...                                Special
# 0             1  ...                                    NaN
# 1             2  ...                                    NaN
# 2             5  ...                                    NaN
# 3             6  ...                                    NaN
# 4             7  ...                                    NaN
# 5             8  ...                                    NaN
# 6             9  ...                                    NaN
# 7            10  ...                                    NaN
# 8            11  ...                                    NaN
# 9            12  ...                                    NaN
# 10           13  ...                                    NaN
# 11           14  ...                                    NaN
# 12           15  ...                                    NaN
# 13           16  ...                                    NaN
# 14           17  ...                                    NaN
# ...
